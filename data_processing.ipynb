# %% [markdown]
# # Data Processing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Set Up Data

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# ### Remove Null Data

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# ## Visualize Data

# %% [markdown]
# ### Histogram

# %%
data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# ### Heat Map

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# ### Coordinate Map

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='latitude', y='longitude', data=data, hue='median_house_value', palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# ## Pre-Process Data

# %% [markdown]
# ### Normalize Distribution for Skewed Data

# %%
data['total_rooms'] = np.log(data['total_rooms'] + 1)
data['total_bedrooms'] = np.log(data['total_bedrooms'] + 1)
data['population'] = np.log(data['population'] + 1)
data['households'] = np.log(data['households'] + 1)

# %%
data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# ### Transform String Data into Boolean Data

# %%
data = data.join(pd.get_dummies(data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0     6.781058        4.867534
# 1        -122.22     37.86                21.0     8.867850        7.009409
# 2        -122.24     37.85                52.0     7.291656        5.252273
# 3        -122.25     37.85                52.0     7.150701        5.463832
# 4        -122.25     37.85                52.0     7.395108        5.638355
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0     7.418181        5.926926
# 20636    -121.21     39.49                18.0     6.548219        5.017280
# 20637    -121.22     39.43                17.0     7.720905        6.186209
# 20638    -121.32     39.43                18.0     7.528869        6.016157
# 20639    -121.24     39.37                16.0     7.932362        6.424869
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 0        5.777652    4.844187         8.3252            452600.0      False
# 1        7.784057    7.037906         8.3014            358500.0      False
# 2        6.208590    5.181784         7.2574            352100.0      False
# 3        6.326149    5.393628         5.6431            341300.0      False
# 4        6.338594    5.560682         3.8462            342200.0      False
# ...           ...         ...            ...                 ...        ...
# 20635    6.740519    5.802118         1.5603             78100.0      False
# 20636    5.877736    4.744932         2.5568             77100.0      False
# 20637    6.915723    6.073045         1.7000             92300.0      False
# 20638    6.609349    5.857933         1.8672             84700.0      False
# 20639    7.235619    6.274762         2.3886             89400.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0       False   False      True       False
# 1       False   False      True       False
# 2       False   False      True       False
# 3       False   False      True       False
# 4       False   False      True       False
# ...       ...     ...       ...         ...
# 20635    True   False     False       False
# 20636    True   False     False       False
# 20637    True   False     False       False
# 20638    True   False     False       False
# 20639    True   False     False       False
#
# [20433 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# ### Engineer New Features

# %%
data['bedroom_ratio'] = data['total_bedrooms'] / data['total_rooms']
data['household_rooms'] = data['total_rooms'] / data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# ### Drop Features

# %%
data = data.drop(['population', 'longitude', 'latitude', 'households', 'total_bedrooms'], axis='columns')
data
# Out:
#        housing_median_age  total_rooms  median_income  median_house_value  \
# 0                    41.0     6.781058         8.3252            452600.0
# 1                    21.0     8.867850         8.3014            358500.0
# 2                    52.0     7.291656         7.2574            352100.0
# 3                    52.0     7.150701         5.6431            341300.0
# 4                    52.0     7.395108         3.8462            342200.0
# ...                   ...          ...            ...                 ...
# 20635                25.0     7.418181         1.5603             78100.0
# 20636                18.0     6.548219         2.5568             77100.0
# 20637                17.0     7.720905         1.7000             92300.0
# 20638                18.0     7.528869         1.8672             84700.0
# 20639                16.0     7.932362         2.3886             89400.0
#
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  \
# 0          False   False   False      True       False       0.717813
# 1          False   False   False      True       False       0.790429
# 2          False   False   False      True       False       0.720313
# 3          False   False   False      True       False       0.764097
# 4          False   False   False      True       False       0.762444
# ...          ...     ...     ...       ...         ...            ...
# 20635      False    True   False     False       False       0.798973
# 20636      False    True   False     False       False       0.766205
# 20637      False    True   False     False       False       0.801228
# 20638      False    True   False     False       False       0.799078
# 20639      False    True   False     False       False       0.809957
#
#        household_rooms
# 0             1.399834
# 1             1.260013
# 2             1.407171
# 3             1.325768
# 4             1.329892
# ...                ...
# 20635         1.278530
# 20636         1.380045
# 20637         1.271340
# 20638         1.285243
# 20639         1.264169
#
# [20433 rows x 11 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# ## Train Model

# %% [markdown]
# ### Split Training and Testing Data

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_test.mean()
# Out:
# housing_median_age    28.781502
# total_rooms            7.630109
# median_income          3.869209
# <1H OCEAN              0.446538
# INLAND                 0.307316
# ISLAND                 0.000245
# NEAR BAY               0.112307
# NEAR OCEAN             0.133594
# bedroom_ratio          0.792591
# household_rooms        1.280079
# dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train)

reg = LinearRegression()
reg.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
X_test_s = scaler.fit_transform(X_test)
reg.score(X_test_s, y_test)
# Out:
# 0.6210362413487409

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()
forest.fit(X_train_s, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test_s, y_test)
# Out:
# 0.6672473485443742

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid = {
    "n_estimators": [100, 200, 300],
    "min_samples_split": [2, 4],
    "max_depth": [None, 4, 8]
}

grid_search = GridSearchCV(forest, param_grid, cv=5, scoring="neg_mean_squared_error", return_train_score=True)

grid_search.fit(X_train_s, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'min_samples_split': [2, 4],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(min_samples_split=4, n_estimators=300)

# %%
grid_search.best_estimator_.score(X_test_s, y_test)
# Out:
# 0.6697104573503849

# %% [markdown]
# ### Store Model

# %%
import pickle

regressor = grid_search.best_estimator_
modelData = {"model": regressor}
with open("model.pkl", "wb") as file:
    pickle.dump(modelData, file)

# "wb" - Write Binary
